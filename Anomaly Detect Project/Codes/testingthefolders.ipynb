# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
train_path= 'C:\\Users\\anira_000\\Desktop\\8th sem\\UCSD\\Data\\UCSDped1\\Train\\'
xlist = []
for a in range(1,35):
    if a<10:
        a='0'+str(a)
    train_path2 = train_path + 'Train0' + str(a)
    train_batch = os.listdir(train_path2)
    for sample in train_batch:
        img_path = str(train_path2)+"\\" + str(sample)
        print(img_path)
        x = Image.open(str(img_path))
        x1=x.resize((227,227),Image.ANTIALIAS)
        numpyarray=np.array(x1)
        #numpyarray=numpyarray/255.0
        xlist.append(numpyarray)
        #x.close() #to close the image train_path= 'C:\\Users\\anira_000\\Desktop\\8th sem\\UCSD\\Data\\UCSDped1\\Train\\'
# Out:
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Train\Train001\001.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Train\Train001\002.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Train\Train001\003.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Train\Train001\004.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Train\Train001\005.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Train\Train001\006.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Train\Train001\007.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Train\Train001\008.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Train\Train001\009.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Train\Train001\010.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Train\Train001\011.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Train\Train001\012.tif
# ...

# %%
test_path= 'C:\\Users\\anira_000\\Desktop\\8th sem\\UCSD\\Data\\UCSDped1\\Test\\'
for a in range(1,22):
    if a<10:
        a='0'+str(a)
    test_path2 = test_path + 'Test0' + str(a)
    test_batch = os.listdir(test_path2)
    for sample in test_batch:
        img_path = str(test_path2)+"\\" + str(sample)
        print(img_path)
        x = Image.open(str(img_path))
        x1=x.resize((227,227),Image.ANTIALIAS)
        numpyarray=np.array(x1)
        #numpyarray=numpyarray/255.0
        xlist.append(numpyarray)
        x.close() #to close the image
# Out:
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test001\001.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test001\002.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test001\003.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test001\004.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test001\005.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test001\006.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test001\007.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test001\008.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test001\009.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test001\010.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test001\011.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test001\012.tif
# ...

# %%
test_path= 'C:\\Users\\anira_000\\Desktop\\8th sem\\UCSD\\Data\\UCSDped1\\Test\\'
xlist2=[]
for a in range(22,35):
    test_path2 = test_path + 'Test0' + str(a)
    test_batch = os.listdir(test_path2)
    for sample in test_batch:
        img_path = str(test_path2)+"\\" + str(sample)
        print(img_path)
        x = Image.open(str(img_path))
        x1=x.resize((227,227),Image.ANTIALIAS)
        numpyarray=np.array(x1)
        #numpyarray=numpyarray/255.0
        xlist2.append(numpyarray)
        x.close() #to close the image
# Out:
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test022\001.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test022\002.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test022\003.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test022\004.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test022\005.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test022\006.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test022\007.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test022\008.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test022\009.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test022\010.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test022\011.tif
# C:\Users\anira_000\Desktop\8th sem\UCSD\Data\UCSDped1\Test\Test022\012.tif
# ...

# %%
a1=np.array(xlist)

# %%
a2=np.array(xlist2)

# %%
print(a1.shape)
print(a2.shape)
del xlist
del xlist2
# Out:
# (11000, 227, 227)
# (2600, 227, 227)

# %%
x_train=np.repeat(a1[...,np.newaxis],3,-1)
x_test=np.repeat(a2[...,np.newaxis],3,-1)

# %%
print(x_train.shape)
print(x_test.shape)
del a1
del a2
# Out:
# (11000, 227, 227, 3)
# (2600, 227, 227, 3)

# %%
x_train=x_train/255.0
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-60-6b9223946f65> in <module>
# ----> 1 x_train=x_train/255.0
#
# MemoryError: Unable to allocate 12.7 GiB for an array with shape (11000, 227, 227, 3) and data type float64

# %%
# Out:
# array([[117, 121, 102, ...,  61,  64,  69],
#        [101,  99,  90, ...,  63,  71,  79],
#        [ 83,  77,  83, ...,  63,  59,  82],
#        ...,
#        [126, 128, 131, ..., 174, 170, 190],
#        [129, 133, 134, ..., 177, 173, 193],
#        [131, 134, 136, ..., 178, 175, 197]], dtype=uint8)

# %%
rgb_batch[0]
# Out:
# array([[[117, 117, 117],
#         [121, 121, 121],
#         [102, 102, 102],
#         ...,
#         [ 61,  61,  61],
#         [ 64,  64,  64],
#         [ 69,  69,  69]],
#
#        [[101, 101, 101],
#         [ 99,  99,  99],
#         [ 90,  90,  90],
#         ...,
#         [ 63,  63,  63],
#         [ 71,  71,  71],
#         [ 79,  79,  79]],
#
#        [[ 83,  83,  83],
#         [ 77,  77,  77],
#         [ 83,  83,  83],
#         ...,
#         [ 63,  63,  63],
#         [ 59,  59,  59],
#         [ 82,  82,  82]],
#
#        ...,
#
#        [[126, 126, 126],
#         [128, 128, 128],
#         [131, 131, 131],
#         ...,
#         [174, 174, 174],
#         [170, 170, 170],
#         [190, 190, 190]],
#
#        [[129, 129, 129],
#         [133, 133, 133],
#         [134, 134, 134],
#         ...,
#         [177, 177, 177],
#         [173, 173, 173],
#         [193, 193, 193]],
#
#        [[131, 131, 131],
#         [134, 134, 134],
#         [136, 136, 136],
# ...

# %%
plt.figure()
plt.imshow(a1[0])

# %%
plt.figure()
plt.imshow(rgb_batch[0])
plt.colorbar()

# %%
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout,Activation

# %%
model=Sequential()
# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(227,227,3), kernel_size=(11,11), strides=4, padding='valid'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='valid'))

# %%
# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=1, padding='same'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='valid'))

# %%
# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=1, padding='same'))
model.add(Activation('relu'))
# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=1, padding='same'))
model.add(Activation('relu'))

# %%
# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=1, padding='same'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='valid'))

# %%
# Passing it to a Fully Connected layer
model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(4096))
model.add(Activation('relu'))
# Add Dropout to prevent overfitting
model.add(Dropout(0.4))
# 2nd Fully Connected Layer
model.add(Dense(4096))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))
# 3rd Fully Connected Layer
model.add(Dense(1000))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))

# %%
model.add(Dense(2))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_27 (Conv2D)           (None, 55, 55, 96)        34944
# _________________________________________________________________
# activation_43 (Activation)   (None, 55, 55, 96)        0
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 27, 27, 96)        0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 27, 27, 256)       614656
# _________________________________________________________________
# activation_44 (Activation)   (None, 27, 27, 256)       0
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 13, 13, 256)       0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 13, 13, 384)       885120
# ...
